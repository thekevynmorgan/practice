# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/y5r80/OneDrive - University of Keele/Documents/Graphviz-14.0.2-win64/bin'

# %%
import graphviz
d=graphviz.Digraph()
d.edges(['JF','JE','FH','FD','EP','EI','HA','PB','PC','IG'])
d

# %%
# !pip install graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: graphviz in c:\users\y5r80\appdata\roaming\python\python311\site-packages (0.21)

# %%
import graphviz
d=graphviz.Digraph()
d.edges(['FD','HA','FH'])
d

# %%
import graphviz
d=graphviz.Digraph()
d.edges(['EP','EI','PB','PC','IG'])
d

# %%
import graphviz
d=graphviz.Digraph()
d.edges(['EC','EI','CB','CD','BA','IG','GF','GH','IK','KJ'])
d

# %%
import graphviz
d=graphviz.Digraph()
d.edges(['EP','EI','PB','PC'])
d

# %%
class Node:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data
    def insert(self,data):
        if self.data:
            if data < self.data:
                if self.left is None:
                    self.left = Node(data)
                else:
                    self.left.insert(data)
        elif data > self.data:
            if self.right is None:
                self.right = Node(data)
            else:
                self.right.insert(data)
        else:
            self.data = data
    def find(self, data, parent = None):
        if data < self.data:
            if self.left is None:
                return None, None
            return self.left.find(data, self)
        elif data > self.data:
            if self.right is None:
                return None, None
            return self.right.find(data, self)
        else: return self, parent
